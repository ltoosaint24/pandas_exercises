# %% [markdown]
# ## Introduction to Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# these are for navigating your system & finding the data
import os
from pathlib import Path

# %%
# where are we?
home = Path.cwd()
home
# Out:
# PosixPath('/Users/austinlasseter/atelier/generalassembly/python-2-dc/07-pandas-intro/code')

# %%
# one level above
home.parent
# Out:
# PosixPath('/Users/austinlasseter/atelier/generalassembly/python-2-dc/07-pandas-intro')

# %%
# where is the data folder?
data_dir = Path.joinpath(home.parent, 'data')
data_dir
# Out:
# PosixPath('/Users/austinlasseter/atelier/generalassembly/python-2-dc/07-pandas-intro/data')

# %%
# what's in it?
os.listdir(data_dir)
# Out:
# ['old-faithful.csv',
#  'collegeadmissions.csv',
#  'u.item',
#  'yelp.json',
#  'msleep.csv',
#  'beer.txt',
#  '.DS_Store',
#  'myresults.csv',
#  'Production.ProductSubcategory.csv',
#  'drinks.csv',
#  'apply functions in pandas.ipynb',
#  'imdb_1000.csv',
#  'imdb_ids.txt',
#  'oracle_10k.csv',
#  'drinks_updated.csv',
#  'airlines.csv',
#  'u.data',
#  'ozone.csv',
#  'vti.csv',
#  'user.tbl',
#  'ufo.csv',
#  'u.user_original',
#  'rossmann-stores.csv',
#  'Sales.SalesOrderHeader.csv',
#  'titanic.csv',
#  'wine.csv',
#  'student_comments.csv',
#  'haystack.csv',
#  'drones.csv',
#  'movie_ratings.tsv',
#  'mtcars.csv',
#  'u.user',
#  'bikeshare.csv',
#  'hitters.csv',
#  'features.csv',
#  'NBA_players_2015.csv',
#  'Sales.SalesOrderDetail.csv',
#  'Production.Product.csv',
#  'bb_results.csv',
#  'chipotle.tsv',
#  'bank-additional.csv',
#  'vehicles_train.csv',
#  'vehicles_test.csv',
#  'stores.csv']

# %%
# define a path to one datafile
filepath = Path.joinpath(home.parent, 'data', 'Production.Product.csv')
filepath
# Out:
# PosixPath('/Users/austinlasseter/atelier/generalassembly/python-2-dc/07-pandas-intro/data/Production.Product.csv')

# %%
# use pandas to read in the datafile
prod = pd.read_csv(filepath, sep='\t')
prod.sample(3)
# Out:
#      ProductID                       Name ProductNumber  MakeFlag  \
# 114        436       Thin-Jam Lock Nut 12       LJ-9080         0
# 266        762           Road-650 Red, 44    BK-R50R-44         1
# 227        723  LL Road Frame - Black, 60    FR-R38B-60         1
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 114                  0    NaN              1000           750        0.0000
# 266                  1    Red               100            75      486.7066
# 227                  1  Black               500           375      204.6251
#
#      ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 114       0.00  ...         NaN   NaN   NaN                   NaN
# 266     782.99  ...          R     L     U                    2.0
# 227     337.22  ...          R     L     U                   14.0
#
#      ProductModelID        SellStartDate          SellEndDate  \
# 114             NaN  2008-04-30 00:00:00                  NaN
# 266            30.0  2011-05-31 00:00:00  2013-05-29 00:00:00
# 227             9.0  2011-05-31 00:00:00                  NaN
#
#     DiscontinuedDate                                 rowguid  \
# 114              NaN  {5D3E589F-4584-406B-B9CC-3C8C060CB9A5}
# 266              NaN  {F247AAAE-12E3-4048-A37B-CCE4A8999E81}
# 227              NaN  {AA95E2A5-E7C4-4B74-B1EA-B52EE3B51537}
#
#                       ModifiedDate
# 114  2014-02-08 10:01:36.827000000
# 266  2014-02-08 10:01:36.827000000
# 227  2014-02-08 10:01:36.827000000
#
# [3 rows x 25 columns]

# %%
# what is prod?
type(prod)
# Out:
# pandas.core.frame.DataFrame

# %%
# how big is it?
prod.shape
# Out:
# (504, 25)

# %%
# what are the columns?
prod.columns
# Out:
# Index(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag',
#        'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost',
#        'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode',
#        'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
# what is the index length?
print(len(prod))
print(prod.index)
# Out:
# 504
# RangeIndex(start=0, stop=504, step=1)

# %% [markdown]
# ### How to call individual columns

# %%
prod.columns
# Out:
# Index(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag',
#        'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost',
#        'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode',
#        'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
# what is the data type in each column?
prod.dtypes
# Out:
# ProductID                  int64
# Name                      object
# ProductNumber             object
# MakeFlag                   int64
# FinishedGoodsFlag          int64
# Color                     object
# SafetyStockLevel           int64
# ReorderPoint               int64
# StandardCost             float64
# ListPrice                float64
# Size                      object
# SizeUnitMeasureCode       object
# WeightUnitMeasureCode     object
# Weight                   float64
# DaysToManufacture          int64
# ProductLine               object
# Class                     object
# Style                     object
# ProductSubcategoryID     float64
# ProductModelID           float64
# SellStartDate             object
# SellEndDate               object
# DiscontinuedDate         float64
# rowguid                   object
# ModifiedDate              object
# dtype: object

# %%
# How to select an individual column
# 3 ways to do this.
# First way. use brackets
prod['Color'].sample(5)
# Out:
# 293       Red
# 461    Yellow
# 123       NaN
# 485    Silver
# 470      Blue
# Name: Color, dtype: object

# %%
# another way.
prod.Color.sample(5)
# Out:
# 311       NaN
# 215      Blue
# 330     Black
# 318     Black
# 384    Silver
# Name: Color, dtype: object

# %%
# Third way (most typing, best results)
prod[['Color']].sample(5)
# Out:
#      Color
# 318  Black
# 6    Black
# 463   Blue
# 196    NaN
# 495  Black

# %%
# The third method allows me to select multiple columns!
list_of_columns = ['Color', 'Style', 'Class'] # first bracket indicates "list"
prod[list_of_columns].sample(5) # second bracket indicates "dataframe filter"
# Out:
#      Color Style Class
# 82     NaN   NaN   NaN
# 394   Blue    U     H
# 365  Black    U    NaN
# 165    NaN   NaN   NaN
# 159    NaN   NaN   NaN

# %%
# Let's create another filter using brackets!
condition = prod['Color']=='Blue'
prod[  condition    ]
# Out:
#      ProductID                         Name ProductNumber  MakeFlag  \
# 215        711       Sport-100 Helmet, Blue     HL-U509-B         0
# 368        864              Classic Vest, S     VE-C304-S         0
# 369        865              Classic Vest, M     VE-C304-M         0
# 370        866              Classic Vest, L     VE-C304-L         0
# 394        890  HL Touring Frame - Blue, 46    FR-T98U-46         1
# 395        891  HL Touring Frame - Blue, 50    FR-T98U-50         1
# 396        892  HL Touring Frame - Blue, 54    FR-T98U-54         1
# 397        893  HL Touring Frame - Blue, 60    FR-T98U-60         1
# 399        895  LL Touring Frame - Blue, 50    FR-T67U-50         1
# 400        896  LL Touring Frame - Blue, 54    FR-T67U-54         1
# 401        897  LL Touring Frame - Blue, 58    FR-T67U-58         1
# 402        898  LL Touring Frame - Blue, 62    FR-T67U-62         1
# 407        903  LL Touring Frame - Blue, 44    FR-T67U-44         1
# 457        953        Touring-2000 Blue, 60    BK-T44U-60         1
# 462        958        Touring-3000 Blue, 54    BK-T18U-54         1
# 463        959        Touring-3000 Blue, 58    BK-T18U-58         1
# 464        960        Touring-3000 Blue, 62    BK-T18U-62         1
# 470        966        Touring-1000 Blue, 46    BK-T79U-46         1
# 471        967        Touring-1000 Blue, 50    BK-T79U-50         1
# 472        968        Touring-1000 Blue, 54    BK-T79U-54         1
# 473        969        Touring-1000 Blue, 60    BK-T79U-60         1
# 474        970        Touring-2000 Blue, 46    BK-T44U-46         1
# 475        971        Touring-2000 Blue, 50    BK-T44U-50         1
# 476        972        Touring-2000 Blue, 54    BK-T44U-54         1
# 482        978        Touring-3000 Blue, 44    BK-T18U-44         1
# 483        979        Touring-3000 Blue, 50    BK-T18U-50         1
#
#      FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 215                  1  Blue                 4             3       13.0863
# 368                  1  Blue                 4             3       23.7490
# 369                  1  Blue                 4             3       23.7490
# 370                  1  Blue                 4             3       23.7490
# 394                  1  Blue               500           375      601.7437
# 395                  1  Blue               500           375      601.7437
# 396                  1  Blue               500           375      601.7437
# 397                  1  Blue               500           375      601.7437
# 399                  1  Blue               500           375      199.8519
# 400                  1  Blue               500           375      199.8519
# 401                  1  Blue               500           375      199.8519
# 402                  1  Blue               500           375      199.8519
# 407                  1  Blue               500           375      199.8519
# 457                  1  Blue               100            75      755.1508
# 462                  1  Blue               100            75      461.4448
# 463                  1  Blue               100            75      461.4448
# 464                  1  Blue               100            75      461.4448
# 470                  1  Blue               100            75     1481.9379
# 471                  1  Blue               100            75     1481.9379
# 472                  1  Blue               100            75     1481.9379
# 473                  1  Blue               100            75     1481.9379
# 474                  1  Blue               100            75      755.1508
# 475                  1  Blue               100            75      755.1508
# 476                  1  Blue               100            75      755.1508
# 482                  1  Blue               100            75      461.4448
# 483                  1  Blue               100            75      461.4448
#
#      ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 215      34.99  ...          S    NaN   NaN                  31.0
# 368      63.50  ...          S    NaN    U                   25.0
# 369      63.50  ...          S    NaN    U                   25.0
# 370      63.50  ...          S    NaN    U                   25.0
# 394    1003.91  ...          T     H     U                   16.0
# 395    1003.91  ...          T     H     U                   16.0
# 396    1003.91  ...          T     H     U                   16.0
# 397    1003.91  ...          T     H     U                   16.0
# 399     333.42  ...          T     L     U                   16.0
# 400     333.42  ...          T     L     U                   16.0
# 401     333.42  ...          T     L     U                   16.0
# 402     333.42  ...          T     L     U                   16.0
# 407     333.42  ...          T     L     U                   16.0
# 457    1214.85  ...          T     M     U                    3.0
# 462     742.35  ...          T     L     U                    3.0
# 463     742.35  ...          T     L     U                    3.0
# 464     742.35  ...          T     L     U                    3.0
# 470    2384.07  ...          T     H     U                    3.0
# 471    2384.07  ...          T     H     U                    3.0
# 472    2384.07  ...          T     H     U                    3.0
# 473    2384.07  ...          T     H     U                    3.0
# 474    1214.85  ...          T     M     U                    3.0
# 475    1214.85  ...          T     M     U                    3.0
# 476    1214.85  ...          T     M     U                    3.0
# 482     742.35  ...          T     L     U                    3.0
# 483     742.35  ...          T     L     U                    3.0
#
#      ProductModelID        SellStartDate SellEndDate DiscontinuedDate  \
# 215            33.0  2011-05-31 00:00:00         NaN              NaN
# 368             1.0  2013-05-30 00:00:00         NaN              NaN
# 369             1.0  2013-05-30 00:00:00         NaN              NaN
# 370             1.0  2013-05-30 00:00:00         NaN              NaN
# 394             7.0  2013-05-30 00:00:00         NaN              NaN
# 395             7.0  2013-05-30 00:00:00         NaN              NaN
# 396             7.0  2013-05-30 00:00:00         NaN              NaN
# 397             7.0  2013-05-30 00:00:00         NaN              NaN
# 399            10.0  2013-05-30 00:00:00         NaN              NaN
# 400            10.0  2013-05-30 00:00:00         NaN              NaN
# 401            10.0  2013-05-30 00:00:00         NaN              NaN
# 402            10.0  2013-05-30 00:00:00         NaN              NaN
# 407            10.0  2013-05-30 00:00:00         NaN              NaN
# 457            35.0  2013-05-30 00:00:00         NaN              NaN
# 462            36.0  2013-05-30 00:00:00         NaN              NaN
# 463            36.0  2013-05-30 00:00:00         NaN              NaN
# 464            36.0  2013-05-30 00:00:00         NaN              NaN
# 470            34.0  2013-05-30 00:00:00         NaN              NaN
# 471            34.0  2013-05-30 00:00:00         NaN              NaN
# 472            34.0  2013-05-30 00:00:00         NaN              NaN
# 473            34.0  2013-05-30 00:00:00         NaN              NaN
# 474            35.0  2013-05-30 00:00:00         NaN              NaN
# 475            35.0  2013-05-30 00:00:00         NaN              NaN
# 476            35.0  2013-05-30 00:00:00         NaN              NaN
# 482            36.0  2013-05-30 00:00:00         NaN              NaN
# 483            36.0  2013-05-30 00:00:00         NaN              NaN
#
#                                     rowguid                   ModifiedDate
# 215  {FD7C0858-4179-48C2-865B-ABD5DFC7BC1D}  2014-02-08 10:01:36.827000000
# 368  {EB423EF3-409D-46FE-B35B-D69970820314}  2014-02-08 10:01:36.827000000
# 369  {2E52F96E-64A1-4069-911C-E3FD6E094A1E}  2014-02-08 10:01:36.827000000
# 370  {3211F5A8-B6C4-48BD-9AA4-D69CB40D97DD}  2014-02-08 10:01:36.827000000
# 394  {8BBD3437-A58B-41A0-9503-FC14B23E7678}  2014-02-08 10:01:36.827000000
# 395  {C4244F0C-ABCE-451B-A895-83C0E6D1F448}  2014-02-08 10:01:36.827000000
# 396  {E9AAE947-6BC3-4909-8937-3E1CDCEC8A8F}  2014-02-08 10:01:36.827000000
# 397  {B01951A4-A581-4D10-9DC2-515DA180F1B8}  2014-02-08 10:01:36.827000000
# 399  {B78ECCCA-FA88-4071-9110-410585127E46}  2014-02-08 10:01:36.827000000
# 400  {0FF799C9-DD11-4B81-AAF7-65410017405B}  2014-02-08 10:01:36.827000000
# 401  {CCD4FA47-7194-4BD0-909B-1FA4BD7916A7}  2014-02-08 10:01:36.827000000
# 402  {08A211A5-DCD2-42D0-9276-64D92D4890A6}  2014-02-08 10:01:36.827000000
# 407  {E9C17BE7-F4DC-465E-AB73-C0198F37BFDD}  2014-02-08 10:01:36.827000000
# 457  {F1BB3957-8D27-47F3-91EC-C71822D11436}  2014-02-08 10:01:36.827000000
# 462  {A3EE6897-52FE-42E4-92EC-7A91E7BB905A}  2014-02-08 10:01:36.827000000
# 463  {23D89CEE-9F44-4F3E-B289-63DE6BA2B737}  2014-02-08 10:01:36.827000000
# 464  {060192C9-BCD9-4260-B729-D6BCFADFB08E}  2014-02-08 10:01:36.827000000
# 470  {86990D54-6EFB-4C53-9974-6C3B0297E222}  2014-02-08 10:01:36.827000000
# 471  {68C0A818-2985-46EB-8255-0FB70919FA24}  2014-02-08 10:01:36.827000000
# 472  {12280A8C-7578-4367-BA71-214BCC1E4792}  2014-02-08 10:01:36.827000000
# 473  {DD70CF36-449A-43FD-839D-A84EE14C849A}  2014-02-08 10:01:36.827000000
# 474  {C0009006-715F-4B76-A05A-1A0D3ADFB49A}  2014-02-08 10:01:36.827000000
# 475  {84ABDA8F-0007-4BCA-9A61-B2DEA58866C3}  2014-02-08 10:01:36.827000000
# 476  {6DCFE2A3-3555-44E4-9116-6F6DBE448B8B}  2014-02-08 10:01:36.827000000
# 482  {4F638E15-2ED0-4193-90CE-47DA580E01DD}  2014-02-08 10:01:36.827000000
# 483  {DE305B62-88FC-465B-B23D-D8C0F7E6D361}  2014-02-08 10:01:36.827000000
#
# [26 rows x 25 columns]

# %%
# Try 2 things:
# call a subset of all columns
# create your own simple filter
# slack out the results as a screenshot.

# %%
# what exactly is the filter doing?
# prod['Color'].head(10) 
prod['Color'].head(10) == 'NaN'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Color, dtype: bool

# %%
# Null values
prod['Color'].isnull()
prod['Color'].notnull().head()
# turn that into a filter
prod[ prod['Color'].notnull() ].head()
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 5        317      LL Crankarm       CA-5965         0                  0
# 6        318      ML Crankarm       CA-6738         0                  0
# 7        319      HL Crankarm       CA-7457         0                  0
# 8        320  Chainring Bolts       CB-2903         0                  0
# 9        321    Chainring Nut       CN-6137         0                  0
#
#     Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 5   Black               500           375           0.0        0.0  ...
# 6   Black               500           375           0.0        0.0  ...
# 7   Black               500           375           0.0        0.0  ...
# 8  Silver              1000           750           0.0        0.0  ...
# 9  Silver              1000           750           0.0        0.0  ...
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 5         NaN    L    NaN                   NaN             NaN
# 6         NaN    M    NaN                   NaN             NaN
# 7         NaN   NaN   NaN                   NaN             NaN
# 8         NaN   NaN   NaN                   NaN             NaN
# 9         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate DiscontinuedDate  \
# 5  2008-04-30 00:00:00         NaN              NaN
# 6  2008-04-30 00:00:00         NaN              NaN
# 7  2008-04-30 00:00:00         NaN              NaN
# 8  2008-04-30 00:00:00         NaN              NaN
# 9  2008-04-30 00:00:00         NaN              NaN
#
#                                   rowguid                   ModifiedDate
# 5  {3C9D10B7-A6B2-4774-9963-C19DCEE72FEA}  2014-02-08 10:01:36.827000000
# 6  {EABB9A92-FA07-4EAB-8955-F0517B4A4CA7}  2014-02-08 10:01:36.827000000
# 7  {7D3FD384-4F29-484B-86FA-4206E276FE58}  2014-02-08 10:01:36.827000000
# 8  {7BE38E48-B7D6-4486-888E-F53C26735101}  2014-02-08 10:01:36.827000000
# 9  {3314B1D7-EF69-4431-B6DD-DC75268BD5DF}  2014-02-08 10:01:36.827000000
#
# [5 rows x 25 columns]

# %%
# Another example of a filter
prod['FinishedGoodsFlag'] == 1
prod  [ prod ['FinishedGoodsFlag']  == 1 ] . head()
# Out:
#      ProductID                       Name ProductNumber  MakeFlag  \
# 209        680  HL Road Frame - Black, 58    FR-R92B-58         1
# 210        706    HL Road Frame - Red, 58    FR-R92R-58         1
# 211        707      Sport-100 Helmet, Red     HL-U509-R         0
# 212        708    Sport-100 Helmet, Black       HL-U509         0
# 213        709     Mountain Bike Socks, M     SO-B909-M         0
#
#      FinishedGoodsFlag  Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 209                  1  Black               500           375     1059.3100
# 210                  1    Red               500           375     1059.3100
# 211                  1    Red                 4             3       13.0863
# 212                  1  Black                 4             3       13.0863
# 213                  1  White                 4             3        3.3963
#
#      ListPrice  ... ProductLine Class Style  ProductSubcategoryID  \
# 209    1431.50  ...          R     H     U                   14.0
# 210    1431.50  ...          R     H     U                   14.0
# 211      34.99  ...          S    NaN   NaN                  31.0
# 212      34.99  ...          S    NaN   NaN                  31.0
# 213       9.50  ...          M    NaN    U                   23.0
#
#      ProductModelID        SellStartDate          SellEndDate  \
# 209             6.0  2008-04-30 00:00:00                  NaN
# 210             6.0  2008-04-30 00:00:00                  NaN
# 211            33.0  2011-05-31 00:00:00                  NaN
# 212            33.0  2011-05-31 00:00:00                  NaN
# 213            18.0  2011-05-31 00:00:00  2012-05-29 00:00:00
#
#     DiscontinuedDate                                 rowguid  \
# 209              NaN  {43DD68D6-14A4-461F-9069-55309D90EA7E}
# 210              NaN  {9540FF17-2712-4C90-A3D1-8CE5568B2462}
# 211              NaN  {2E1EF41A-C08A-4FF6-8ADA-BDE58B64A712}
# 212              NaN  {A25A44FB-C2DE-4268-958F-110B8D7621E2}
# 213              NaN  {18F95F47-1540-4E02-8F1F-CC1BCB6828D0}
#
#                       ModifiedDate
# 209  2014-02-08 10:01:36.827000000
# 210  2014-02-08 10:01:36.827000000
# 211  2014-02-08 10:01:36.827000000
# 212  2014-02-08 10:01:36.827000000
# 213  2014-02-08 10:01:36.827000000
#
# [5 rows x 25 columns]

# %%
# You can call a single (or multiple) column(s) from filtered results
prod  [ prod ['FinishedGoodsFlag']  == 1 ][['FinishedGoodsFlag', 'Color', 'ListPrice']].head(5)
# Out:
#      FinishedGoodsFlag  Color  ListPrice
# 209                  1  Black    1431.50
# 210                  1    Red    1431.50
# 211                  1    Red      34.99
# 212                  1  Black      34.99
# 213                  1  White       9.50

# %% [markdown]
# ### Calculate some simple summary stats on your dataframe

# %%
# describe all columns
prod.describe()
# Out:
#         ProductID    MakeFlag  FinishedGoodsFlag  SafetyStockLevel  \
# count  504.000000  504.000000         504.000000        504.000000
# mean   673.039683    0.474206           0.585317        535.150794
# std    229.373142    0.499830           0.493157        374.112954
# min      1.000000    0.000000           0.000000          4.000000
# 25%    447.750000    0.000000           0.000000        100.000000
# 50%    747.500000    0.000000           1.000000        500.000000
# 75%    873.250000    1.000000           1.000000       1000.000000
# max    999.000000    1.000000           1.000000       1000.000000
#
#        ReorderPoint  StandardCost    ListPrice       Weight  \
# count    504.000000    504.000000   504.000000   205.000000
# mean     401.363095    258.602961   438.666250    74.069220
# std      280.584715    461.632808   773.602843   182.166588
# min        3.000000      0.000000     0.000000     2.120000
# 25%       75.000000      0.000000     0.000000     2.880000
# 50%      375.000000     23.372200    49.990000    17.900000
# 75%      750.000000    317.075825   564.990000    27.350000
# max      750.000000   2171.294200  3578.270000  1050.000000
#
#        DaysToManufacture  ProductSubcategoryID  ProductModelID  \
# count         504.000000            295.000000      295.000000
# mean            1.103175             12.294915       37.444068
# std             1.492616              9.860135       34.025442
# min             0.000000              1.000000        1.000000
# 25%             0.000000              2.000000       11.000000
# 50%             1.000000             12.000000       26.000000
# 75%             1.000000             17.000000       48.500000
# max             4.000000             37.000000      128.000000
#
#        DiscontinuedDate
# count               0.0
# mean                NaN
# std                 NaN
# min                 NaN
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max                 NaN

# %%
# describe a single column
prod['ListPrice'].describe()
# Out:
# count     504.000000
# mean      438.666250
# std       773.602843
# min         0.000000
# 25%         0.000000
# 50%        49.990000
# 75%       564.990000
# max      3578.270000
# Name: ListPrice, dtype: float64

# %%
# Describe a subset of columns
prod[['ListPrice', 'Weight', 'StandardCost']].describe()
# Out:
#          ListPrice       Weight  StandardCost
# count   504.000000   205.000000    504.000000
# mean    438.666250    74.069220    258.602961
# std     773.602843   182.166588    461.632808
# min       0.000000     2.120000      0.000000
# 25%       0.000000     2.880000      0.000000
# 50%      49.990000    17.900000     23.372200
# 75%     564.990000    27.350000    317.075825
# max    3578.270000  1050.000000   2171.294200

# %%
# Describe a subset of these 8 statistics (for the entire dataframe)
prod.mean()
prod.median()
prod.min()
prod.max()
prod.count()
prod.quantile(.25)
# Out:
# ProductID               447.75
# MakeFlag                  0.00
# FinishedGoodsFlag         0.00
# SafetyStockLevel        100.00
# ReorderPoint             75.00
# StandardCost              0.00
# ListPrice                 0.00
# Weight                    2.88
# DaysToManufacture         0.00
# ProductSubcategoryID      2.00
# ProductModelID           11.00
# DiscontinuedDate           NaN
# Name: 0.25, dtype: float64

# %%
# Describe a subset of these 8 statistics (for a single column)
prod['ListPrice'].mean()
prod['ListPrice'].median()
prod['ListPrice'].min()
prod['ListPrice'].max()
prod['ListPrice'].count()
prod['ListPrice'].quantile(.5)
# Out:
# 49.99

# %%
# Describe a subset of these 8 statistics (for a subset of columns)
prod[['ListPrice', 'Weight']].mean()
prod[['ListPrice', 'Weight']].median()
prod[['ListPrice', 'Weight']].min()
prod[['ListPrice', 'Weight']].max()
prod[['ListPrice', 'Weight']].count()
prod[['ListPrice', 'Weight']].quantile(.5)
# Out:
# ListPrice    49.99
# Weight       17.90
# Name: 0.5, dtype: float64

# %% [markdown]
# ## Renaming some columns

# %%
prod.columns
# Out:
# Index(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag',
#        'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost',
#        'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WeightUnitMeasureCode',
#        'Weight', 'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
prod.rename(columns={'WeightUnitMeasureCode': 'WUMC'}, inplace=True)
print(prod.columns)
# Out:
# Index(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag',
#        'Color', 'SafetyStockLevel', 'ReorderPoint', 'StandardCost',
#        'ListPrice', 'Size', 'SizeUnitMeasureCode', 'WUMC', 'Weight',
#        'DaysToManufacture', 'ProductLine', 'Class', 'Style',
#        'ProductSubcategoryID', 'ProductModelID', 'SellStartDate',
#        'SellEndDate', 'DiscontinuedDate', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
# overwrite file
prod.to_csv('filename.csv')

# %%
# do this with multiple columns
prod.rename(columns={'ProductID':'ID', 'Name':'ProdName', 'ProductNumber':'Number'}, inplace=True)
prod.head()
# Out:
#     ID               ProdName   Number  MakeFlag  FinishedGoodsFlag Color  \
# 0    1        Adjustable Race  AR-5381         0                  0   NaN
# 1    2           Bearing Ball  BA-8327         0                  0   NaN
# 2    3        BB Ball Bearing  BE-2349         1                  0   NaN
# 3    4  Headset Ball Bearings  BE-2908         0                  0   NaN
# 4  316                  Blade  BL-2036         1                  0   NaN
#
#    SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ... ProductLine  \
# 0              1000           750           0.0        0.0  ...         NaN
# 1              1000           750           0.0        0.0  ...         NaN
# 2               800           600           0.0        0.0  ...         NaN
# 3               800           600           0.0        0.0  ...         NaN
# 4               800           600           0.0        0.0  ...         NaN
#
#   Class Style  ProductSubcategoryID  ProductModelID        SellStartDate  \
# 0   NaN   NaN                   NaN             NaN  2008-04-30 00:00:00
# 1   NaN   NaN                   NaN             NaN  2008-04-30 00:00:00
# 2   NaN   NaN                   NaN             NaN  2008-04-30 00:00:00
# 3   NaN   NaN                   NaN             NaN  2008-04-30 00:00:00
# 4   NaN   NaN                   NaN             NaN  2008-04-30 00:00:00
#
#   SellEndDate DiscontinuedDate                                 rowguid  \
# 0         NaN              NaN  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}
# 1         NaN              NaN  {58AE3C20-4F3A-4749-A7D4-D568806CC537}
# 2         NaN              NaN  {9C21AED2-5BFA-4F18-BCB8-F11638DC2E4E}
# 3         NaN              NaN  {ECFED6CB-51FF-49B5-B06C-7D8AC834DB8B}
# 4         NaN              NaN  {E73E9750-603B-4131-89F5-3DD15ED5FF80}
#
#                     ModifiedDate
# 0  2014-02-08 10:01:36.827000000
# 1  2014-02-08 10:01:36.827000000
# 2  2014-02-08 10:01:36.827000000
# 3  2014-02-08 10:01:36.827000000
# 4  2014-02-08 10:01:36.827000000
#
# [5 rows x 25 columns]

# %% [markdown]
# ## A few common operations with Pandas

# %%
# Show all values of a categorical variable
prod['Color'].value_counts() # don't display null
prod['Color'].value_counts(dropna=False) # do display nulls
# Out:
# NaN             248
# Black            93
# Silver           43
# Red              38
# Yellow           36
# Blue             26
# Multi             8
# Silver/Black      7
# White             4
# Grey              1
# Name: Color, dtype: int64

# %%
# display frequencies sorted by the index
prod['Style'].value_counts().sort_index()
# Out:
# M       7
# U     176
# W      28
# Name: Style, dtype: int64

# %%
# What if I just want a list of the colors?
prod['Color'].value_counts().index
# Out:
# Index(['Black', 'Silver', 'Red', 'Yellow', 'Blue', 'Multi', 'Silver/Black',
#        'White', 'Grey'],
#       dtype='object')

# %%
# What if I just want the freqs?
prod['Color'].value_counts().values
# Out:
# array([93, 43, 38, 36, 26,  8,  7,  4,  1])

# %%
# How many UNIQUE colors are there?
len(prod['Color'].value_counts().index)
prod['Color'].nunique()
# Out:
# 9

# %%
# List the unique colors
prod['Color'].value_counts(dropna=False).index
prod['Color'].unique()
# Out:
# array([nan, 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)
